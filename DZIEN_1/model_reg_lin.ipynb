# %%
library(ggplot2)
library(tidyverse)

# %%
dataFrame<-read.csv('income.data_.csv')
head(dataFrame)
# Out:
# <table class="dataframe">
# <caption>A data.frame: 6 × 3</caption>
# <thead>
# 	<tr><th></th><th scope=col>X</th><th scope=col>income</th><th scope=col>happiness</th></tr>
# 	<tr><th></th><th scope=col>&lt;int&gt;</th><th scope=col>&lt;dbl&gt;</th><th scope=col>&lt;dbl&gt;</th></tr>
# </thead>
# <tbody>
# 	<tr><th scope=row>1</th><td>1</td><td>3.862647</td><td>2.314489</td></tr>
# 	<tr><th scope=row>2</th><td>2</td><td>4.979381</td><td>3.433490</td></tr>
# 	<tr><th scope=row>3</th><td>3</td><td>4.923957</td><td>4.599373</td></tr>
# 	<tr><th scope=row>4</th><td>4</td><td>3.214372</td><td>2.791114</td></tr>
# 	<tr><th scope=row>5</th><td>5</td><td>7.196409</td><td>5.596398</td></tr>
# 	<tr><th scope=row>6</th><td>6</td><td>3.729643</td><td>2.458556</td></tr>
# </tbody>
# </table>

# %%
x<-dataFrame$income
y<-dataFrame$happiness
plot(x,y)

# %%
model<-lm(y~x)
model
# Out:
# Call:
# lm(formula = y ~ x)
#
# Coefficients:
# (Intercept)            x
#      0.2043       0.7138

# %%
model_summary<-summary(model)
intercept_value<-model_summary$coefficients[1,1]
intercept_value
# Out:
# 0.204270396204178

# %%
model_summary
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.02479 -0.48526  0.04078  0.45898  2.37805
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.20427    0.08884   2.299   0.0219 *
# x            0.71383    0.01854  38.505   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7181 on 496 degrees of freedom
# Multiple R-squared:  0.7493,	Adjusted R-squared:  0.7488
# F-statistic:  1483 on 1 and 496 DF,  p-value: < 2.2e-16
